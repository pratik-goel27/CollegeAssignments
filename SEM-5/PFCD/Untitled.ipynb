# %%
n = int(input("Enter a num: "))
if n%2 == 0:
    print(f"The num {n} is even.")
else:
    print(f"The num {n} is odd.")

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# Enter a year:  2020
# 2020 is a leap year.

# %%
import math
a = 1
n = int(input("Enter a num: "))
for i in range(2, int(math.sqrt(n))+1):
    if n % i == 0:
        print(f"The num {n} is not a prime num.")
        a = 0;
        break
if a == 1:
    print(f"The num {n} is a prime num.")

# %%
num = int(input("Enter a num: "))
sum = 0
flag = True
for i in range(2, num+1):
    flag = True
    for j in range(2, int(math.sqrt(i))+1):
        if i % j == 0:
            flag = False
            break
    if flag:
        sum = sum + i
print(sum)

# %%
flag = True
while flag:
    num = int(input("Enter a num: "))
    if num > 0:
        flag = False
        if num % 2 == 0:
            print("Even num: ", 2*num)
        else :
            print("Odd num: ",num**2)

# %%
num = input("Enter a num: ")
if num.isdigit():
    num = int(num)
    remainder = num % 5
    match remainder:
        case 0:
            print("Remainder is 0")
        case 1:
            print("Remainder is 1")
        case 2:
            print("Remainder is 2")
        case 3: 
            print("Remainder is 3")
        case 4:
            print("Remainder is 4")
else :
    print("Invalid Input.")

# %%
# string = input("Enter a string: ")

# for i in range(len(string)):
#     for j in range(i, len(string)):
#         for k in range(i,j+1):
#             print(string[k], end="")
#         print("\n")

string = input("Enter a string: ")

for i in range(len(string)):
    for j in range(i, len(string)):
        print(string[i:j+1])

# %%
flag = True
while flag:
    user_input = input("Enter expression (or type exit to stop)")

# %%
import statistics 
data = [1,2,3,2,3,4,4,4,5,4,5,6]
mean_val = statistics.mean(data)
median_val = statistics.median(data)
mode_val = statistics.mode(data)
print(mean_val)
print(median_val)
print(mode_val)

# %%
n = 15
sum = 0
flag = False
for i in range(1,n+1):
    if n%i == 0:
        sum += i
        if sum == n:
            flag = True
            print("Perfect Number")
            break
if flag == False:
    print("Not a Perfect Number")

# %%
cnt = 0
for i in range(100,1000+1):
    if i % 5 == 0 or i % 6 == 0:
        print(i,end=" ")
        cnt += 1
        if cnt == 10:
            cnt = 0
            print("\n")
# Out:
# 100 102 105 108 110 114 115 120 125 126
#
# 130 132 135 138 140 144 145 150 155 156
#
# 160 162 165 168 170 174 175 180 185 186
#
# 190 192 195 198 200 204 205 210 215 216
#
# 220 222 225 228 230 234 235 240 245 246
#
# 250 252 255 258 260 264 265 270 275 276
#
# 280 282 285 288 290 294 295 300 305 306
#
# 310 312 315 318 320 324 325 330 335 336
#
# 340 342 345 348 350 354 355 360 365 366
#
# 370 372 375 378 380 384 385 390 395 396
#
# 400 402 405 408 410 414 415 420 425 426
#
# 430 432 435 438 440 444 445 450 455 456
#
# 460 462 465 468 470 474 475 480 485 486
#
# 490 492 495 498 500 504 505 510 515 516
#
# 520 522 525 528 530 534 535 540 545 546
#
# 550 552 555 558 560 564 565 570 575 576
#
# 580 582 585 588 590 594 595 600 605 606
#
# 610 612 615 618 620 624 625 630 635 636
#
# 640 642 645 648 650 654 655 660 665 666
#
# 670 672 675 678 680 684 685 690 695 696
#
# 700 702 705 708 710 714 715 720 725 726
#
# 730 732 735 738 740 744 745 750 755 756
#
# ...

# %%
for i in range(1,100+1):
    if i % 7 == 0:
        continue
    else:
        print(i,end=" ")

# %%
n = 1234
m = n
ans = 0
while n > 0:
    ans = ans*10 + n%10
    n //= 10
print(f"The rev of the num {m} is: {ans}")

# %%
n = 9875
while True:
    sum = 0
    while n > 0:
        sum += n%10
        n //= 10
    n = sum
    if 0 < n < 9:
        break
print(n)
# Out:
# 2
